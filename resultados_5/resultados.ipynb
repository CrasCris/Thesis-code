# %%
import os
import pandas as pd

# Ruta de la carpeta que contiene los CSVs
ruta_carpeta = './'

# Cargar todos los archivos CSV
dfs = []
for archivo in os.listdir(ruta_carpeta):
    if archivo.endswith('.csv'):
        df = pd.read_csv(os.path.join(ruta_carpeta, archivo))
        df['Fuente'] = archivo  # Agregamos una columna para identificar el origen
        dfs.append(df)

# Combinar todos los DataFrames en uno solo
df_todos = pd.concat(dfs, ignore_index=True)

# %%
import pandas as pd
import os
import numpy as np

# Definir las métricas deseadas\ nMETRICAS = ['SMAPE', 'MAE', 'MSE']
METRICAS = ['SMAPE', 'MAE', 'MSE']

def load_results(filename):
    """
    Carga el CSV y extrae el número de intervalo a partir de la columna 'Intervalos Acumulados'.
    Se asume que la cadena tiene el formato 'Intervalos 1 a X'.
    """
    df = pd.read_csv(filename)
    # Extraer el número final del intervalo para usarlo como índice
    df['Intervalo'] = df['Intervalos Acumulados'].str.extract(r'a (\d+)').astype(int)
    df.set_index('Intervalo', inplace=True)
    return df


def extraer_metricas(df, metricas=METRICAS):
    """
    Asegura que el DataFrame tenga las columnas indicadas en 'metricas'.
    Si falta alguna, se agrega con valores NaN.
    Se reordena el DataFrame según el orden especificado en 'metricas'.
    """
    for met in metricas:
        if met not in df.columns:
            df[met] = np.nan
    return df[metricas]


def obtener_tabla(horizonte):
    # Diccionario para almacenar DataFrames de cada modelo
    tablas = {}

    # Archivos para los modelos LSTM
    lstm_files = {
        'LSTM-7': f"lstm_7_{horizonte}.csv",
        'LSTM-14': f"lstm_14_{horizonte}.csv",
        'LSTM-21': f"lstm_21_{horizonte}.csv"
    }
    for key, file in lstm_files.items():
        if os.path.exists(file):
            df = load_results(file)
            tablas[key] = extraer_metricas(df, METRICAS)
        else:
            raise FileNotFoundError(f"Archivo no encontrado: {file}")

    # Archivo para TimesFM
    timesfm_file = f"timesfm_{horizonte}.csv"
    if os.path.exists(timesfm_file):
        df_timesfm = load_results(timesfm_file)
        tablas['TimesFM'] = extraer_metricas(df_timesfm, METRICAS)
    else:
        raise FileNotFoundError(f"Archivo no encontrado: {timesfm_file}")

    # Archivo para Time-MOE
    time_moe_file = f"time-moe_{horizonte}.csv"
    if os.path.exists(time_moe_file):
        df_time_moe = load_results(time_moe_file)
        tablas['Time-MOE'] = extraer_metricas(df_time_moe, METRICAS)
    else:
        raise FileNotFoundError(f"Archivo no encontrado: {time_moe_file}")

    # Combinar todos los DataFrames en uno con columnas de MultiIndex
    tabla_resumen = pd.concat(tablas, axis=1)
    tabla_resumen.index.name = 'Intervalo'
    return tabla_resumen


def stack_table(tabla):
    """
    Convierte la tabla de formato ancho (con columnas MultiIndex: Modelo y Métrica)
    a un formato "apilado" donde cada fila representa un intervalo y una métrica,
    y las columnas corresponden a los modelos.
    """
    tabla_apilada = tabla.stack(level=1)
    tabla_apilada.index.names = ['Intervalo', 'Métrica']
    return tabla_apilada


def highlight_min_max(row):
    min_val = row.min()
    max_val = row.max()
    estilos = []
    for v in row:
        if v == min_val and v == max_val:
            estilos.append("")
        elif v == min_val:
            estilos.append("background-color: blue; color: white")
        elif v == max_val:
            estilos.append("background-color: red; color: white")
        else:
            estilos.append("")
    return estilos


def style_stacked(tabla, horizonte):
    return (tabla.style
            .format("{:.2f}")
            .apply(highlight_min_max, axis=1)
            .set_caption(f"Comparación de Modelos por Métrica (por fila: mínimo azul, máximo rojo) - {horizonte} días"))


# Obtener las tablas para los distintos horizontes
tabla_15 = obtener_tabla(15)
tabla_30 = obtener_tabla(30)

# Reorganizar la tabla (apilando las métricas en el índice)
tabla_15_apilada = stack_table(tabla_15)
tabla_30_apilada = stack_table(tabla_30)

# Mostrar las tablas con estilo en Jupyter Notebook
display(style_stacked(tabla_15_apilada, '15'))
display(style_stacked(tabla_30_apilada, '30'))

# Opcional: guardar las tablas a CSV (sin aplicar el estilo)
tabla_15_apilada.to_csv('tabla_apilada_horizonte_15_1.csv')
tabla_30_apilada.to_csv('tabla_apilada_horizonte_30_2.csv')


#USANDO STANDARD SCALER
# Out:
# C:\Users\criju\AppData\Local\Temp\ipykernel_30308\2780580387.py:77: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   tabla_apilada = tabla.stack(level=1)
# C:\Users\criju\AppData\Local\Temp\ipykernel_30308\2780580387.py:77: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   tabla_apilada = tabla.stack(level=1)
# <style type="text/css">
# #T_ecf16_row0_col2, #T_ecf16_row1_col2, #T_ecf16_row2_col2, #T_ecf16_row3_col0, #T_ecf16_row4_col0, #T_ecf16_row5_col0, #T_ecf16_row6_col4, #T_ecf16_row7_col4, #T_ecf16_row8_col4, #T_ecf16_row9_col4, #T_ecf16_row10_col3, #T_ecf16_row11_col3, #T_ecf16_row12_col3, #T_ecf16_row13_col2, #T_ecf16_row14_col2, #T_ecf16_row15_col0, #T_ecf16_row16_col0, #T_ecf16_row17_col0, #T_ecf16_row18_col4, #T_ecf16_row19_col4, #T_ecf16_row20_col4, #T_ecf16_row21_col4, #T_ecf16_row22_col4, #T_ecf16_row23_col4 {
#   background-color: blue;
#   color: white;
# }
# #T_ecf16_row0_col4, #T_ecf16_row1_col4, #T_ecf16_row2_col4, #T_ecf16_row3_col4, #T_ecf16_row4_col4, #T_ecf16_row5_col4, #T_ecf16_row6_col3, #T_ecf16_row7_col3, #T_ecf16_row8_col3, #T_ecf16_row9_col0, #T_ecf16_row10_col0, #T_ecf16_row11_col0, #T_ecf16_row12_col4, #T_ecf16_row13_col4, #T_ecf16_row14_col4, #T_ecf16_row15_col3, #T_ecf16_row16_col3, #T_ecf16_row17_col3, #T_ecf16_row18_col3, #T_ecf16_row19_col3, #T_ecf16_row20_col3, #T_ecf16_row21_col3, #T_ecf16_row22_col0, #T_ecf16_row23_col0 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_ecf16">
#   <caption>Comparación de Modelos por Métrica (por fila: mínimo azul, máximo rojo) - 15 días</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecf16_level0_col0" class="col_heading level0 col0" >LSTM-7</th>
#       <th id="T_ecf16_level0_col1" class="col_heading level0 col1" >LSTM-14</th>
#       <th id="T_ecf16_level0_col2" class="col_heading level0 col2" >LSTM-21</th>
#       <th id="T_ecf16_level0_col3" class="col_heading level0 col3" >TimesFM</th>
#       <th id="T_ecf16_level0_col4" class="col_heading level0 col4" >Time-MOE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Intervalo</th>
#       <th class="index_name level1" >Métrica</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecf16_level0_row0" class="row_heading level0 row0" rowspan="3">1</th>
#       <th id="T_ecf16_level1_row0" class="row_heading level1 row0" >SMAPE</th>
#       <td id="T_ecf16_row0_col0" class="data row0 col0" >23.92</td>
#       <td id="T_ecf16_row0_col1" class="data row0 col1" >20.52</td>
#       <td id="T_ecf16_row0_col2" class="data row0 col2" >19.97</td>
#       <td id="T_ecf16_row0_col3" class="data row0 col3" >49.96</td>
#       <td id="T_ecf16_row0_col4" class="data row0 col4" >64.19</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level1_row1" class="row_heading level1 row1" >MAE</th>
#       <td id="T_ecf16_row1_col0" class="data row1 col0" >108.53</td>
#       <td id="T_ecf16_row1_col1" class="data row1 col1" >66.50</td>
#       <td id="T_ecf16_row1_col2" class="data row1 col2" >63.05</td>
#       <td id="T_ecf16_row1_col3" class="data row1 col3" >161.83</td>
#       <td id="T_ecf16_row1_col4" class="data row1 col4" >194.17</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level1_row2" class="row_heading level1 row2" >MSE</th>
#       <td id="T_ecf16_row2_col0" class="data row2 col0" >21740.22</td>
#       <td id="T_ecf16_row2_col1" class="data row2 col1" >7963.03</td>
#       <td id="T_ecf16_row2_col2" class="data row2 col2" >7659.86</td>
#       <td id="T_ecf16_row2_col3" class="data row2 col3" >39464.28</td>
#       <td id="T_ecf16_row2_col4" class="data row2 col4" >52630.54</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level0_row3" class="row_heading level0 row3" rowspan="3">2</th>
#       <th id="T_ecf16_level1_row3" class="row_heading level1 row3" >SMAPE</th>
#       <td id="T_ecf16_row3_col0" class="data row3 col0" >21.32</td>
#       <td id="T_ecf16_row3_col1" class="data row3 col1" >21.72</td>
#       <td id="T_ecf16_row3_col2" class="data row3 col2" >22.12</td>
#       <td id="T_ecf16_row3_col3" class="data row3 col3" >41.53</td>
#       <td id="T_ecf16_row3_col4" class="data row3 col4" >42.78</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level1_row4" class="row_heading level1 row4" >MAE</th>
#       <td id="T_ecf16_row4_col0" class="data row4 col0" >107.53</td>
#       <td id="T_ecf16_row4_col1" class="data row4 col1" >108.84</td>
#       <td id="T_ecf16_row4_col2" class="data row4 col2" >110.94</td>
#       <td id="T_ecf16_row4_col3" class="data row4 col3" >182.36</td>
#       <td id="T_ecf16_row4_col4" class="data row4 col4" >186.16</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level1_row5" class="row_heading level1 row5" >MSE</th>
#       <td id="T_ecf16_row5_col0" class="data row5 col0" >18197.20</td>
#       <td id="T_ecf16_row5_col1" class="data row5 col1" >18266.44</td>
#       <td id="T_ecf16_row5_col2" class="data row5 col2" >19062.50</td>
#       <td id="T_ecf16_row5_col3" class="data row5 col3" >49539.47</td>
#       <td id="T_ecf16_row5_col4" class="data row5 col4" >53474.49</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level0_row6" class="row_heading level0 row6" rowspan="3">3</th>
#       <th id="T_ecf16_level1_row6" class="row_heading level1 row6" >SMAPE</th>
#       <td id="T_ecf16_row6_col0" class="data row6 col0" >31.02</td>
#       <td id="T_ecf16_row6_col1" class="data row6 col1" >28.52</td>
#       <td id="T_ecf16_row6_col2" class="data row6 col2" >32.75</td>
#       <td id="T_ecf16_row6_col3" class="data row6 col3" >36.13</td>
#       <td id="T_ecf16_row6_col4" class="data row6 col4" >25.32</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level1_row7" class="row_heading level1 row7" >MAE</th>
#       <td id="T_ecf16_row7_col0" class="data row7 col0" >283.57</td>
#       <td id="T_ecf16_row7_col1" class="data row7 col1" >262.06</td>
#       <td id="T_ecf16_row7_col2" class="data row7 col2" >292.76</td>
#       <td id="T_ecf16_row7_col3" class="data row7 col3" >325.83</td>
#       <td id="T_ecf16_row7_col4" class="data row7 col4" >246.38</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level1_row8" class="row_heading level1 row8" >MSE</th>
#       <td id="T_ecf16_row8_col0" class="data row8 col0" >129816.71</td>
#       <td id="T_ecf16_row8_col1" class="data row8 col1" >112757.68</td>
#       <td id="T_ecf16_row8_col2" class="data row8 col2" >137508.53</td>
#       <td id="T_ecf16_row8_col3" class="data row8 col3" >181618.79</td>
#       <td id="T_ecf16_row8_col4" class="data row8 col4" >111229.68</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level0_row9" class="row_heading level0 row9" rowspan="3">4</th>
#       <th id="T_ecf16_level1_row9" class="row_heading level1 row9" >SMAPE</th>
#       <td id="T_ecf16_row9_col0" class="data row9 col0" >139.50</td>
#       <td id="T_ecf16_row9_col1" class="data row9 col1" >126.82</td>
#       <td id="T_ecf16_row9_col2" class="data row9 col2" >137.34</td>
#       <td id="T_ecf16_row9_col3" class="data row9 col3" >74.47</td>
#       <td id="T_ecf16_row9_col4" class="data row9 col4" >70.67</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level1_row10" class="row_heading level1 row10" >MAE</th>
#       <td id="T_ecf16_row10_col0" class="data row10 col0" >98.78</td>
#       <td id="T_ecf16_row10_col1" class="data row10 col1" >73.90</td>
#       <td id="T_ecf16_row10_col2" class="data row10 col2" >93.82</td>
#       <td id="T_ecf16_row10_col3" class="data row10 col3" >24.57</td>
#       <td id="T_ecf16_row10_col4" class="data row10 col4" >26.32</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level1_row11" class="row_heading level1 row11" >MSE</th>
#       <td id="T_ecf16_row11_col0" class="data row11 col0" >9795.14</td>
#       <td id="T_ecf16_row11_col1" class="data row11 col1" >5500.62</td>
#       <td id="T_ecf16_row11_col2" class="data row11 col2" >8842.29</td>
#       <td id="T_ecf16_row11_col3" class="data row11 col3" >638.38</td>
#       <td id="T_ecf16_row11_col4" class="data row11 col4" >1047.21</td>
#     </tr>
#     <tr>
#       <th id="T_ecf16_level0_row12" class="row_heading level0 row12" rowspan="3">5</th>
#       <th id="T_ecf16_level1_row12" class="row_heading level1 row12" >SMAPE</th>
#       <td id="T_ecf16_row12_col0" class=
# <style type="text/css">
# #T_84a28_row0_col2, #T_84a28_row1_col2, #T_84a28_row2_col2, #T_84a28_row3_col2, #T_84a28_row4_col2, #T_84a28_row5_col2, #T_84a28_row6_col4, #T_84a28_row7_col4, #T_84a28_row8_col4, #T_84a28_row9_col4, #T_84a28_row10_col3, #T_84a28_row11_col3, #T_84a28_row12_col2, #T_84a28_row13_col2, #T_84a28_row14_col2, #T_84a28_row15_col0, #T_84a28_row16_col0, #T_84a28_row17_col0, #T_84a28_row18_col4, #T_84a28_row19_col4, #T_84a28_row20_col4, #T_84a28_row21_col4, #T_84a28_row22_col4, #T_84a28_row23_col4 {
#   background-color: blue;
#   color: white;
# }
# #T_84a28_row0_col4, #T_84a28_row1_col4, #T_84a28_row2_col4, #T_84a28_row3_col3, #T_84a28_row4_col3, #T_84a28_row5_col3, #T_84a28_row6_col3, #T_84a28_row7_col3, #T_84a28_row8_col3, #T_84a28_row9_col3, #T_84a28_row10_col2, #T_84a28_row11_col2, #T_84a28_row12_col4, #T_84a28_row13_col4, #T_84a28_row14_col4, #T_84a28_row15_col3, #T_84a28_row16_col3, #T_84a28_row17_col3, #T_84a28_row18_col3, #T_84a28_row19_col3, #T_84a28_row20_col3, #T_84a28_row21_col3, #T_84a28_row22_col3, #T_84a28_row23_col3 {
#   background-color: red;
#   color: white;
# }
# </style>
# <table id="T_84a28">
#   <caption>Comparación de Modelos por Métrica (por fila: mínimo azul, máximo rojo) - 30 días</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84a28_level0_col0" class="col_heading level0 col0" >LSTM-7</th>
#       <th id="T_84a28_level0_col1" class="col_heading level0 col1" >LSTM-14</th>
#       <th id="T_84a28_level0_col2" class="col_heading level0 col2" >LSTM-21</th>
#       <th id="T_84a28_level0_col3" class="col_heading level0 col3" >TimesFM</th>
#       <th id="T_84a28_level0_col4" class="col_heading level0 col4" >Time-MOE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Intervalo</th>
#       <th class="index_name level1" >Métrica</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84a28_level0_row0" class="row_heading level0 row0" rowspan="3">1</th>
#       <th id="T_84a28_level1_row0" class="row_heading level1 row0" >SMAPE</th>
#       <td id="T_84a28_row0_col0" class="data row0 col0" >47.48</td>
#       <td id="T_84a28_row0_col1" class="data row0 col1" >48.95</td>
#       <td id="T_84a28_row0_col2" class="data row0 col2" >37.74</td>
#       <td id="T_84a28_row0_col3" class="data row0 col3" >106.30</td>
#       <td id="T_84a28_row0_col4" class="data row0 col4" >111.60</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level1_row1" class="row_heading level1 row1" >MAE</th>
#       <td id="T_84a28_row1_col0" class="data row1 col0" >128.52</td>
#       <td id="T_84a28_row1_col1" class="data row1 col1" >91.78</td>
#       <td id="T_84a28_row1_col2" class="data row1 col2" >84.29</td>
#       <td id="T_84a28_row1_col3" class="data row1 col3" >198.98</td>
#       <td id="T_84a28_row1_col4" class="data row1 col4" >203.80</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level1_row2" class="row_heading level1 row2" >MSE</th>
#       <td id="T_84a28_row2_col0" class="data row2 col0" >52636.13</td>
#       <td id="T_84a28_row2_col1" class="data row2 col1" >12082.63</td>
#       <td id="T_84a28_row2_col2" class="data row2 col2" >11347.86</td>
#       <td id="T_84a28_row2_col3" class="data row2 col3" >63915.79</td>
#       <td id="T_84a28_row2_col4" class="data row2 col4" >66013.03</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level0_row3" class="row_heading level0 row3" rowspan="3">2</th>
#       <th id="T_84a28_level1_row3" class="row_heading level1 row3" >SMAPE</th>
#       <td id="T_84a28_row3_col0" class="data row3 col0" >19.08</td>
#       <td id="T_84a28_row3_col1" class="data row3 col1" >20.25</td>
#       <td id="T_84a28_row3_col2" class="data row3 col2" >18.84</td>
#       <td id="T_84a28_row3_col3" class="data row3 col3" >49.26</td>
#       <td id="T_84a28_row3_col4" class="data row3 col4" >44.55</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level1_row4" class="row_heading level1 row4" >MAE</th>
#       <td id="T_84a28_row4_col0" class="data row4 col0" >86.35</td>
#       <td id="T_84a28_row4_col1" class="data row4 col1" >90.96</td>
#       <td id="T_84a28_row4_col2" class="data row4 col2" >85.83</td>
#       <td id="T_84a28_row4_col3" class="data row4 col3" >187.61</td>
#       <td id="T_84a28_row4_col4" class="data row4 col4" >174.87</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level1_row5" class="row_heading level1 row5" >MSE</th>
#       <td id="T_84a28_row5_col0" class="data row5 col0" >12856.54</td>
#       <td id="T_84a28_row5_col1" class="data row5 col1" >14605.49</td>
#       <td id="T_84a28_row5_col2" class="data row5 col2" >11949.30</td>
#       <td id="T_84a28_row5_col3" class="data row5 col3" >54042.86</td>
#       <td id="T_84a28_row5_col4" class="data row5 col4" >48678.73</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level0_row6" class="row_heading level0 row6" rowspan="3">3</th>
#       <th id="T_84a28_level1_row6" class="row_heading level1 row6" >SMAPE</th>
#       <td id="T_84a28_row6_col0" class="data row6 col0" >28.83</td>
#       <td id="T_84a28_row6_col1" class="data row6 col1" >27.55</td>
#       <td id="T_84a28_row6_col2" class="data row6 col2" >29.25</td>
#       <td id="T_84a28_row6_col3" class="data row6 col3" >45.57</td>
#       <td id="T_84a28_row6_col4" class="data row6 col4" >23.59</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level1_row7" class="row_heading level1 row7" >MAE</th>
#       <td id="T_84a28_row7_col0" class="data row7 col0" >210.64</td>
#       <td id="T_84a28_row7_col1" class="data row7 col1" >198.20</td>
#       <td id="T_84a28_row7_col2" class="data row7 col2" >207.92</td>
#       <td id="T_84a28_row7_col3" class="data row7 col3" >316.34</td>
#       <td id="T_84a28_row7_col4" class="data row7 col4" >178.67</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level1_row8" class="row_heading level1 row8" >MSE</th>
#       <td id="T_84a28_row8_col0" class="data row8 col0" >80640.93</td>
#       <td id="T_84a28_row8_col1" class="data row8 col1" >70278.25</td>
#       <td id="T_84a28_row8_col2" class="data row8 col2" >76340.54</td>
#       <td id="T_84a28_row8_col3" class="data row8 col3" >172432.14</td>
#       <td id="T_84a28_row8_col4" class="data row8 col4" >64629.66</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level0_row9" class="row_heading level0 row9" rowspan="3">4</th>
#       <th id="T_84a28_level1_row9" class="row_heading level1 row9" >SMAPE</th>
#       <td id="T_84a28_row9_col0" class="data row9 col0" >120.84</td>
#       <td id="T_84a28_row9_col1" class="data row9 col1" >116.03</td>
#       <td id="T_84a28_row9_col2" class="data row9 col2" >129.72</td>
#       <td id="T_84a28_row9_col3" class="data row9 col3" >194.29</td>
#       <td id="T_84a28_row9_col4" class="data row9 col4" >96.50</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level1_row10" class="row_heading level1 row10" >MAE</th>
#       <td id="T_84a28_row10_col0" class="data row10 col0" >76.40</td>
#       <td id="T_84a28_row10_col1" class="data row10 col1" >69.04</td>
#       <td id="T_84a28_row10_col2" class="data row10 col2" >92.63</td>
#       <td id="T_84a28_row10_col3" class="data row10 col3" >41.80</td>
#       <td id="T_84a28_row10_col4" class="data row10 col4" >62.95</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level1_row11" class="row_heading level1 row11" >MSE</th>
#       <td id="T_84a28_row11_col0" class="data row11 col0" >5870.11</td>
#       <td id="T_84a28_row11_col1" class="data row11 col1" >4798.95</td>
#       <td id="T_84a28_row11_col2" class="data row11 col2" >8613.47</td>
#       <td id="T_84a28_row11_col3" class="data row11 col3" >2038.77</td>
#       <td id="T_84a28_row11_col4" class="data row11 col4" >6227.16</td>
#     </tr>
#     <tr>
#       <th id="T_84a28_level0_row12" class="row_heading level0 row12" rowspan="3">5</th>
#       <th id="T_84a28_level1_row12" class="row_heading level1 row12" >SMAPE</th>
#       <td id="T_84a28_row12_col0" class="
